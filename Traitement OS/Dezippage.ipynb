# %%
import os, zipfile

dir_name = 'C:\\Users\\baccam\\Documents\\Export du SIM du 230722\\test dezip'
extension = ".zip"

os.chdir(dir_name) # change directory from working dir to dir with files

for item in os.listdir(dir_name): # loop through items in dir
    if item.endswith(extension): # check for ".zip" extension
        file_name = os.path.abspath(item) # get full path of files
        zip_ref = zipfile.ZipFile(file_name) # create zipfile object
        zip_ref.extractall(dir_name) # extract file to dir
        zip_ref.close() # close file
        os.remove(file_name) # delete zipped file

# %%
import os
import zipfile

base_dir = 'C:\\Users\\baccam\\Documents\\Export du SIM du 230722\\test dezip' # absolute path to the data folder
extension = ".zip"

os.chdir(base_dir)  # change directory from working dir to dir with files


def unpack_all_in_dir(_dir):
    for item in os.listdir(_dir):  # loop through items in dir
        abs_path = os.path.join(_dir, item)  # absolute path of dir or file
        if item.endswith(extension):  # check for ".zip" extension
            file_name = os.path.abspath(abs_path)  # get full path of file
            zip_ref = zipfile.ZipFile(file_name)  # create zipfile object
            zip_ref.extractall(_dir)  # extract file to dir
            zip_ref.close()  # close file
        elif os.path.isdir(abs_path):
            unpack_all_in_dir(abs_path)  # recurse this function with inner folder


unpack_all_in_dir(base_dir)

# %%
import os
import shutil
source_dir = 'C:\\Users\\baccam\\Documents\\Export du SIM du 230722\\output'
image_dir = 'C:\\Users\\baccam\\Documents\\Export du SIM du 230722\\testdezip'

file_names = os.listdir(source_dir)

def move_pngs(src, dst):
    for file_name in os.listdir(src):
        fullname = os.path.join(src, file_name)
        if os.path.isdir(fullname) and fullname != dst:
            move_pngs(fullname, dst)
        elif file_name.endswith('.doc'):
            shutil.move(fullname, dst)
            
move_pngs(source_dir, image_dir)
move_pngs(os.path.join(source_dir, 'XPYL'), image_dir)

# %%
import os
from fnmatch import fnmatch

root = 'C:\\Users\\baccam\\Documents\\Export du SIM du 230722\\test dezip'
pattern = "*.pdf"

for path, subdirs, files in os.walk(root):
    for name in files:
        if fnmatch(name, pattern):
            print(os.path.join(path, name))
# Out:
# C:\Users\baccam\Documents\Export du SIM du 230722\test dezip\00111001\Suivi\Rapport final\ANR-16-CE29-0004_CRF_RapportFinal_63307.pdf
# C:\Users\baccam\Documents\Export du SIM du 230722\test dezip\2complex\Suivi\Rapport final\ANR-16-CE18-0002_CRF_RapportFinal_62726.pdf
# C:\Users\baccam\Documents\Export du SIM du 230722\test dezip\2MAC-CSP\Suivi\Rapport final\ANR-16-CE08-0019_CRF_RapportFinal_63474.pdf
# C:\Users\baccam\Documents\Export du SIM du 230722\test dezip\2PhotonInsight\Suivi\Rapport final\ANR-16-CE08-0020_CRF_RapportFinal_64670.pdf
# C:\Users\baccam\Documents\Export du SIM du 230722\test dezip\3D3M\Suivi\Rapport final\ANR-16-CE37-0002_CRF_RapportFinal_63910.pdf
# C:\Users\baccam\Documents\Export du SIM du 230722\test dezip\4DCollab\Suivi\Rapport final\ANR-16-CE10-0006_CRF_RapportFinal_65585.pdf
# C:\Users\baccam\Documents\Export du SIM du 230722\test dezip\ACCURATE\Suivi\Rapport final\ANR-16-CE28-0016_CRF_RapportFinal_64616.pdf
# ...
